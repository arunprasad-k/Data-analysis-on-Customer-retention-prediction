# %% [markdown]
# # CUSTOMER RETENTION PROJECT

# %% [markdown]
# # 1.Problem statement
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %% [markdown]
# # 2.Importing Libraries and the Dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#loading the dataset
df=pd.read_excel(r"C:\Customer_retention_dataset.xlsx")
df.head(2)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
#
#   7 How do you access the internet while shopping on-line?  \
# 0                                            Dial-up
# 1                                              Wi-Fi
#
# ...

# %%
#since the column names are complex,lets change the name
df.columns=["gender","age","city","pincode","years of shopping online","no.of.times purchased online","accessing internet","device used","screen size","os","browser used","channel follow","reaching store after 1st visit","time to explore","preferred payment option","abandoning cart frequently","why abandon the bag","easy to read","info on product comparision","info on purchase decision","info on product stated clearly","ease of navigation","processing speed","user friendly interface","easy Payment methods",
           "trust on online retail","empathy towards customers","gaurantee on privacy","availability on communication channel","benifits and discounts","enjoyment is derived","convenient/flexible","return/replacement policy",
           "gaining access to loyalty","display quality info satisty customers","user derive satisfaction","Net Benefit from shopping online can lead to users satisfaction","User satisfaction cannot exist without trust","Offering a variety of product in several category","Provision of complete and relevant product information","monetary savings",
           "The Convenience of patronizing the online retailer","Shopping on the website gives sense of adventure","Shopping on e-tailer enhances social status","feel gratification shopping on favorite e-tailer","Shopping on the website helps fulfill roles","Getting value for money spent",'Tick any (or all) of the online retailers you have shopped from',
           'Easy to use website/app','Visual appealing web-page layout', 'Wild variety of product on offer','Complete, relevant description information of products',
       'speed of website/app','Reliability of the website/app','Quickness to complete purchase','Availability of several payment options','Speedy order delivery ',
       'Privacy of customer info','Security of customer financial info','Perceived Trustworthiness','Presence of online assistance through multi-channel','Longer time to get log in',
       'Longer time in displaying graphics and photos','Late declaration of price','Longer page loading time','Limited mode of payment on most products','Longer delivery period','Change in website/Application design',
       'disruption moving from one page to another','Website is as efficient as before','Which of the Indian online retailer would you recommend to a friend?']
df.head(2)
# Out:
#    gender          age   city  pincode years of shopping online  \
# 0    Male  31-40 years  Delhi   110009            Above 4 years
# 1  Female  21-30 years  Delhi   110030            Above 4 years
#
#   no.of.times purchased online accessing internet device used screen size  \
# 0                  31-40 times            Dial-up     Desktop      Others
# 1           41 times and above              Wi-Fi  Smartphone  4.7 inches
#
#                       os  ... Longer time to get log in  \
# 0  Window/windows Mobile  ...                 Amazon.in
# 1                IOS/Mac  ...   Amazon.in, Flipkart.com
#
#   Longer time in displaying graphics and photos Late declaration of price  \
# 0                                     Amazon.in              Flipkart.com
# 1                                    Myntra.com              snapdeal.com
#
#   Longer page loading time Limited mode of payment on most products  \
# 0             Flipkart.com                                Amazon.in
# ...

# %% [markdown]
# # 3. Basic Statistics of Our DataSet

# %%
#Basic Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   gender                                                                269 non-null    object
#  1   age                                                                   269 non-null    object
#  2   city                                                                  269 non-null    object
#  3   pincode                                                               269 non-null    int64
#  4   years of shopping online                                              269 non-null    object
#  5   no.of.times purchased online                                          269 non-null    object
# ...

# %%
#column names
df.columns
# Out:
# Index(['gender', 'age', 'city', 'pincode', 'years of shopping online',
#        'no.of.times purchased online', 'accessing internet', 'device used',
#        'screen size', 'os', 'browser used', 'channel follow',
#        'reaching store after 1st visit', 'time to explore',
#        'preferred payment option', 'abandoning cart frequently',
#        'why abandon the bag', 'easy to read', 'info on product comparision',
#        'info on purchase decision', 'info on product stated clearly',
#        'ease of navigation', 'processing speed', 'user friendly interface',
#        'easy Payment methods', 'trust on online retail',
#        'empathy towards customers', 'gaurantee on privacy',
#        'availability on communication channel', 'benifits and discounts',
#        'enjoyment is derived', 'convenient/flexible',
#        'return/replacement policy', 'gaining access to loyalty',
#        'display quality info satisty customers', 'user derive satisfaction',
# ...

# %%
#datatypes of the Attributes
df.dtypes
# Out:
# gender                                                                  object
# age                                                                     object
# city                                                                    object
# pincode                                                                  int64
# years of shopping online                                                object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# disruption moving from one page to another                              object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# ###### Observation:
#
#    - The attribute **pincode** is of type integer
#    - The remaining all attributes is of type object

# %%
#No of rows and columns
df.shape
# Out:
# (269, 71)

# %% [markdown]
# ###### observation
# The dataset contains 269 rows and 71 columns

# %% [markdown]
# # 4. Finding Missing Values

# %%
df.isnull().sum()
# Out:
# gender                                                                  0
# age                                                                     0
# city                                                                    0
# pincode                                                                 0
# years of shopping online                                                0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# disruption moving from one page to another                              0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#Graphical Visuvalization of Missing values
plt.figure(figsize=(18,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### observation:
#
#     we find no missing value in the dataset

# %% [markdown]
# # 5.Exploratory Data Analysis

# %% [markdown]
# ## 5.1 Non-Graphical Univariate Analysis

# %%
#finding the unique values and value counts
#using for loop
for column in df.columns:
    print("unique values are:",df[column].unique())
    print("value counts",df[column].value_counts())
    print("**"*10)
    print("\n")
# Out:
# unique values are: ['Male' 'Female']
# value counts Female    181
# Male       88
# Name: gender, dtype: int64
# ********************
#
#
# unique values are: ['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
# value counts 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: age, dtype: int64
# ********************
#
#
# unique values are: ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# value counts Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: city, dtype: int64
# ********************
#
#
# unique values are: [110009 110030 201308 132001 530068 110011 110018 173229 110039 244001
# ...

# %% [markdown]
# ## 5.2 Graphical Univariate Analysis

# %% [markdown]
# ### 5.2.1 Gender

# %%
#Attribute "gender"
df.groupby('gender').size()
# Out:
# gender
# Female    181
# Male       88
# dtype: int64

# %%
#Visuvalization
plt.figure(figsize=(8,6))
sizes = [181,88]
labels = ['female','male']
colors = ['yellow', 'blue']
explode = [0.1,0]
plt.pie(sizes,labels= labels,colors= colors,explode = explode, autopct = '%1.1f%%',shadow = True)
plt.show()

# %% [markdown]
# ###### observation:
#    The demographics of the respondents showed that the number of females was higher with a share of 68%, while 32% were males.

# %% [markdown]
# ### 5.2.2 Age

# %%
#Visualization
plt.figure(figsize=(10,5))
sns.countplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# ### observation:
#
#    - Here we can see that people of age group between __31-40 years__  seems to use the online retailing the most when compared to other age groups
#
#    - whereas the people of age group of __less than 20 years__ and __51 years and above__ were the least to use online retailing

# %% [markdown]
# ### 5.2.3 city

# %%
#Visualization
plt.figure(figsize=(15,5))
sns.countplot(df["city"])
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %% [markdown]
# ###### Observation:
#    - Regarding city wise the capital of India **Delhi** placed at the top among other cities with respect to people who shop online from ,followed by **Bangalore**.
#    - The least amoug them being **Bulandshahr**

# %% [markdown]
# ### 5.2.4 System Quality

# %%
plt.figure(figsize=(25,25))
sns.set_style("whitegrid")
plt.subplot(3,2,1)
sns.countplot(df["device used"]).set_title("Which device do you use to access the online shopping?")
plt.subplot(3,2,2)
sns.countplot(df["screen size"]).set_title(" What is the screen size of your mobile device?")
plt.subplot(3,2,3)
sns.countplot(df["os"]).set_title("What is the operating system (OS) of your device?")
plt.subplot(3,2,4)
sns.countplot(df["browser used"]).set_title("What browser do you run on your device to access the website?")
plt.subplot(3,2,5)
sns.countplot(df["accessing internet"]).set_title("How do you access the internet while shopping on-line?")
plt.subplot(3,2,6)
sns.countplot(df["channel follow"]).set_title("channel followed on favorite online store for the first time?")
# Out:
# Text(0.5, 1.0, 'channel followed on favorite online store for the first time?')

# %% [markdown]
# ###### Observation:
#
#    - from the count plot we can infer that the user who use **smartphone** device were more in number to access the online shopping
#    - people who uses smartphone prefer a big screen. from the graph we can see that most of the people (around 100) uses the phone with screen size of **5.5 inches**.
#    - Around 120 users use their device with **windows/windows** mobile as their operating system
#    - Most people prefer **google chrome** as the browser while accesing internet
#    - while accessing internet most people uses **mobile internet** to access the online shopping websites
#    - people prefer **search engine** as the channel followed on favorite online store for the first time. very least prefer the other two

# %% [markdown]
# ### 5.2.5 User satisfaction

# %%
plt.figure(figsize=(20,20))
sns.set_style("whitegrid")
plt.subplot(3,2,1)
sns.countplot(df["enjoyment is derived"]).set_title("Enjoyment is derived from shopping online?")
plt.subplot(3,2,2)
sns.countplot(df["convenient/flexible"]).set_title("Shopping online is convenient and flexible")
plt.subplot(3,2,3)
sns.countplot(df["display quality info satisty customers"]).set_title("Displaying quality Info on the website improves satisfaction of customers")
plt.subplot(3,2,4)
sns.countplot(df["user derive satisfaction"]).set_title("User derive satisfaction while shopping on a good quality website or application")
plt.subplot(3,2,5)
sns.countplot(df["Net Benefit from shopping online can lead to users satisfaction"]).set_title("Net Benefit derived from shopping online can lead to users satisfaction")
plt.subplot(3,2,6)
sns.countplot(df["User satisfaction cannot exist without trust"]).set_title("User satisfaction cannot exist without trust")
# Out:
# Text(0.5, 1.0, 'User satisfaction cannot exist without trust')

# %% [markdown]
# ###### Observation:
#
#    - **Enjoyment is derived from shopping online?**- For this question people around 85 in count strongly agree that shopping online gives them enjoyment whereas only 18 person disagree to this opinion
#    - **Shopping online is convenient and flexible?**- From the graph we infer that people strongly agree that shopping online is convenient anf flexible rather than offline shopping.
#    - **Displaying quality Info on the website improves satisfaction of customers?**- The data clearly shows 3 kind of people opt for this statement.In that option around 170 people strongly agree that Displaying quality Info on the website improves their satisfaction
#    - **User derive satisfaction while shopping on a good quality website or application?**- From the data we infer that most of te people strongly agree that a good website satisfy them while shopping online.
#    - **Net Benefit derived from shopping online can lead to users satisfaction?** - Most of the people strongly agree that they get satisfied by doing online shopping whith net benifits
#    - **User satisfaction cannot exist without trust** - The count plot clearly shows people mostly believe that User satisfaction cannot exist without trust. Nearly 120 people strongly agree to it where as 115 people chooses agree

# %% [markdown]
# ### 5.2.6 Information Quality

# %%
plt.figure(figsize=(20,20))
sns.set_style("whitegrid")
plt.subplot(3,3,1)
sns.countplot(df["info on product comparision"]).set_title("Info on similar product to the one highlighted is important for product comparison")
plt.subplot(3,3,2)
sns.countplot(df["convenient/flexible"]).set_title("Complete info on listed seller and product being offered is important for purchase decision.")
plt.subplot(3,3,3)
sns.countplot(df["info on product stated clearly"]).set_title("All relevant info on listed products must be stated clearly")
plt.tight_layout()

# %% [markdown]
# ###### Observation:
#
#    - Most of the respondent **strongly agrees** that Info on similar product to the one highlighted is important for product comparison
#    - very few **disagree** to the fact that Complete info on listed seller and product being offered is important for purchase decision. Around 150 respondent **strongly agree** to it.
#    - only people around 110 choose **strongly agree** whereas around 130 choose **agree** on relevant info on listed products must be stated clearly. This clearly shows the e-retailer must improve their information quliality on the respective field

# %% [markdown]
# ## 5.3 Bivariate Analysis

# %% [markdown]
# ## 5.3.1 Trust

# %%
#Here we will see analysis between the gender and the Trust factors
plt.figure(figsize=(20,20))
sns.set_style("whitegrid")
plt.subplot(3,2,1)
#gender vs trust on online retail
sns.countplot(x="gender",data=df,hue="trust on online retail")
#gender vs User satisfaction cannot exist without trust
plt.subplot(3,2,2)
sns.countplot(x="gender",data=df,hue="User satisfaction cannot exist without trust")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ###### Observation:
#    - Trust and commitment are the central tenets in building successful long‐term relationships in the online retailing context. Here female respondants **strongly agree that trust is an important factor** for successful customer retention
#    - Most of the Male Respondants doesn't agree that user satisfation cannot exist without trust.But seeing female respondants view it is complete reciprocal to the male respondants view.over 85 female users **agree that trust is the main factor for user satsifaction**

# %% [markdown]
# ## 5.3.2 Service quality

# %%
#Here we will see analysis between the gender and the service quality
plt.figure(figsize=(20,20))
sns.set_style("whitegrid")
plt.subplot(3,2,1)
#Gender vs user friendly interface
sns.countplot(x="gender",data=df,hue="user friendly interface")
plt.subplot(3,2,2)
#Gender vs user easy Payment methods
sns.countplot(x="gender",data=df,hue="easy Payment methods")
plt.subplot(3,2,3)
#Gender vs empathy towards customers
sns.countplot(x="gender",data=df,hue="empathy towards customers")
plt.subplot(3,2,4)
#Gender vs gaurantee on privacy
sns.countplot(x="gender",data=df,hue="gaurantee on privacy")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ###### Observation:
#    - Among the respondents,female customers **strongly agrees** to the fact that the E-retail Shopping must be **user friendly** interface. But the male Respondents doesnt agree much to this fact.
#    - Female Respondents believe that **easier payment method** to shop online will be best for better E-retail shopping.Around 130 female users **strongly agrees** this whereas only half of the male respondents w.r.t female users agrees to this.
#    - showing empathy helps customers to feel that their concerns matter. Female users **strongly agrees** that **empathy towards customers** will increase the trust on service quality whereas many male respondants doesnt agree to this point.
#    - Handling and protection of the sensitive personal information of the users is very important. Female respondants around 140 **strongly agrees** on **Gaurentee on privacy** increase the customer retention and male respondants around 50  **strongly agrees** to it.

# %% [markdown]
# # 5.4 Categorical encoding using Label-Encoder

# %%
#From the given data-set we can infer that all the data types are categorical
#we convert them to integer type by using the label encoder method
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for columns in df.columns:
    df[columns]=le.fit_transform(df[columns])

# %% [markdown]
# - since the Encoding is done we proceed with Feature Engineering

# %% [markdown]
# # 5.5 Feature Engineering
#
#  Before moving further in this section first let's find the correlation between the features using Heatmap.

# %% [markdown]
# ## 5.5.1 correlation

# %%
#Finding correlation between attributes
cor=df.corr()
cor
# Out:
#                                                       gender       age  \
# gender                                              1.000000  0.046169
# age                                                 0.046169  1.000000
# city                                                0.080912  0.113712
# pincode                                            -0.289628 -0.133946
# years of shopping online                           -0.057096 -0.087847
# ...                                                      ...       ...
# Longer delivery period                              0.060838 -0.156173
# Change in website/Application design               -0.164818 -0.134558
# disruption moving from one page to another         -0.256638 -0.018825
# Website is as efficient as before                   0.055663 -0.008582
# Which of the Indian online retailer would you r... -0.003372 -0.135263
#
#                                                         city   pincode  \
# ...

# %%
#Visualization of Correlation
#using Heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
sns.heatmap((cor),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5.6 Data Cleaning
#
# We will start the process of finding outliers by running the summary statistics on the variables. This is done using the **describe ()** function below, which provides a statistical summary of all the quantitative variables.

# %%
df.describe()
# Out:
#            gender         age        city     pincode  \
# count  269.000000  269.000000  269.000000  269.000000
# mean     0.327138    1.330855    4.494424   18.163569
# std      0.470042    1.183774    3.187687   10.343865
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    2.000000   10.000000
# 50%      0.000000    1.000000    4.000000   19.000000
# 75%      1.000000    2.000000    7.000000   24.000000
# max      1.000000    4.000000   10.000000   38.000000
#
#        years of shopping online  no.of.times purchased online  \
# count                269.000000                    269.000000
# mean                   2.323420                      3.237918
# std                    1.176357                      1.739331
# min                    0.000000                      0.000000
# 25%                    1.000000                      2.000000
# 50%                    3.000000                      3.000000
# ...

# %% [markdown]
# ###### key observation
#     1)There are no missing values
#
#     2)Here we find that the mean is higher than median in most of the columns
#
# If the mean is higher than the median, the distribution is positively skewed.
#
#     3)the maximum and the 75% doesnt had any range of difference.we observe that the difference is normal
#
#  we infer that we may have very less outliers or May be not.

# %% [markdown]
# ### Remove unnecessary columns which are redundant that does not contribute to the model prediction.

# %%
# Removing Unecessary Columns
df.drop(columns = ['pincode'], inplace = True)

# %% [markdown]
# ## 5.6.1 Outliers

# %%
#Plotting Outliers
collist=df.columns.values
ncol=6
nrow=15
plt.figure(figsize=(nrow,5*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color="red",orient="v")
    plt.tight_layout()

# %% [markdown]
# ###### Plot insight
#
#    - The boxplot shows that there are some amount of outliers in most of the column attributes.

# %% [markdown]
# ## 5.6.2  Treating Outliers

# %%
#Removing Outliers
#Z-score Techinique
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.43416114, 0.2800127 , 0.78397694, ..., 1.40519246, 0.98469733,
#         1.52727829],
#        [0.69727172, 1.12634321, 0.78397694, ..., 0.16163354, 0.52322768,
#         0.25533445],
#        [0.69727172, 1.12634321, 0.15539334, ..., 0.94504654, 0.98469733,
#         1.10329701],
#        ...,
#        [0.69727172, 0.56631782, 1.41256055, ..., 1.33675303, 0.98469733,
#         1.01660938],
#        [0.69727172, 2.25897885, 1.73035746, ..., 0.55334004, 1.32265095,
#         1.01660938],
#        [0.69727172, 0.56631782, 0.46968514, ..., 1.40519246, 0.98469733,
#         1.01660938]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#        159, 162, 196, 207, 234, 237, 262], dtype=int64), array([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10, 10, 10], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (249, 70)

# %%
df.shape
# Out:
# (269, 70)

# %%
## Percentage Loss
loss_of_data=(269-249)/269*100
loss_of_data
# Out:
# 7.434944237918216

# %% [markdown]
# ###### Outliers Overview
# when we try to remove outliers it results in loss of data around 7%.
#
# since the loss of data is not much as expected,so proceeding with outlier removal

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Exploratory data analysis is one of the key competencies of a data scientist at a startup. You should be able to dig into a new data set and determine how to improve your product based on the results. EDA is a way of understanding the shape of a data set, exploring correlations within the data, and determining if there’s a signal for modeling an outcome based on the different features.
#
# - Here we have done the EDA for the given dataset.
#
# - From here we can proceed with train test split and predit using Machine learning algorithm
